# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
import pyautogui
import pyperclip
import webbrowser
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup


chrome_options = Options()

# 브라우저 꺼짐 방지
chrome_options.add_experimental_option('detach', True)

# 불필요한 에러 메시지 노출 방지
chrome_options.add_experimental_option('excludeSwitches', ['enable-logging'])

driver = webdriver.Chrome(options = chrome_options)

driver.maximize_window()
time.sleep(1)

driver.get('https://shopping.naver.com/ns/home')

time.sleep(2)
such = driver.find_element(By.CSS_SELECTOR,'#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > input')
such.send_keys("노트북")
such.send_keys(Keys.ENTER)


html = driver.page_source
soup = BeautifulSoup(html,"html.parser")

mylink = []

items = soup.select("#composite-card-list > div > ul > li")
for item in items:
    name = item.select_one("strong").text
    price = item.select_one('span.priceTag_inner_price__TctbK').text
    c = {
        '상품': name,
        '가격': price
    }
    mylink.append(c)


for data in mylink:
    print(data)
# Out:
# {'상품': '베이직북16 업무용 사무용 노트북 인강용 가벼운 16GB/512GB 영상편집 윈도우11', '가격': '638,000원'}
# {'상품': '베이직북14 프로 WIN 16GB/512GB 영상편집 게이밍 노트북 사무용 가벼운 대학생', '가격': '670,000원'}
# {'상품': '베이직북14 pro 윈도우 한컴오피스 노트북 사무용 영상편집 업무용 인강용 가벼운 초경량', '가격': '619,000원'}
# {'상품': 'HP 옴니북 울트라 플립 14 U7 258V 32GB 2.8K 터치 OLED 충전식 펜 HDMI 어댑터 AI 노트북', '가격': '2,399,000원'}
# {'상품': '베이직북16 사무용 노트북 업무용 인강용 가벼운 게이밍 영상편집 랩탑 고사양 윈도우11', '가격': '548,000원'}
# {'상품': '벨킨 C타입 멀티 허브 F4U092bt 아이폰15 맥북 프로 에어 아이패드 노트북 멀티포트 SD카드 LAN 6in1', '가격': '99,000원'}
# {'상품': '2024 LG그램 인텔 Ultra5 16GB 256GB 가벼운 노트북 사무용 대학생 인강용', '가격': '1,199,000원'}
# {'상품': '베이직북14 3세대 사무용 노트북 가벼운 인강용 업무용 대학생 포토샵 초경량 윈도우11', '가격': '388,000원'}
# {'상품': 'LG전자 울트라PC 15인치 사무용 인강용 업무용 학생용 저렴한 가성비 LG노트북', '가격': '519,000원'}
# {'상품': '[혜택가 127만+바꿔보상] 삼성전자 갤럭시북4 프로 NT960XGQ-A51A 16인치 사무용 휴대용 가벼운 대학생 포토샵 AI 노트북', '가격': '1,599,000원'}
# {'상품': '삼성 갤럭시북 인강용 사무용 업무용 가성비 윈도우11 저가 싼 태블릿 노트북 추천', '가격': '409,000원'}
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
import pyautogui
import pyperclip
import webbrowser
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup

chrome_options = Options()

# 브라우저 꺼짐 방지
chrome_options.add_experimental_option('detach', True)

# 불필요한 에러 메시지 노출 방지
chrome_options.add_experimental_option('excludeSwitches', ['enable-logging'])

driver = webdriver.Chrome(options = chrome_options)

driver.maximize_window()
time.sleep(1)
driver.get('https://land.naver.com/')


time.sleep(2)
such = driver.find_element(By.ID,'queryInputHeader')
such.send_keys("성남시 수정구")
such.send_keys(Keys.ENTER)

maps = []
informations = driver.find_elements(By.CSS_SELECTOR,'div.marker_complex_inner')

for i,information in enumerate(informations[:5]):
    
    place = information.find_element(By.CSS_SELECTOR, ".complex_infos > .complex_title").get_attribute("textContent")

    price = information.find_element(By.CSS_SELECTOR,'.complex_infos .price_default').text
    
    if not price:
        continue

    print(f"{place} --> {price}")

    maps.append ({
        '이름': place,
        '가격': price
    })
print()
print(maps)
# Out:
# 피더하우스(실버주택) --> 3.9억
# 청솔계룡 --> 10.4억
# 상록라이프 --> 18억
# 까치마을우방,우성 --> 17.5억
#
# [{'이름': '피더하우스(실버주택)', '가격': '3.9억'}, {'이름': '청솔계룡', '가격': '10.4억'}, {'이름': '상록라이프', '가격': '18억'}, {'이름': '까치마을우방,우성', '가격': '17.5억'}]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Chrome()
driver.get("https://new.land.naver.com/")

time.sleep(5)

search_box = driver.find_element(By.CSS_SELECTOR, "#land_search")
search_box.send_keys("강남구 역삼동")
search_box.submit()

maps = []

items = driver.find_elements(By.CSS_SELECTOR, "div.marker_complex_inner")

for i, item in enumerate(items[:5]):
    # place = item.find_element(By.CSS_SELECTOR, ".complex_infos > .complex_title").text
    place = item.find_element(By.CSS_SELECTOR, ".complex_infos > .complex_title").get_attribute("textContent")
    # place = driver.execute_script(f"""
    #     var element = document.querySelectorAll('.complex_infos > .complex_title')[{i}];
    #     return element ? element.textContent.trim() : null;
    # """)
    price = item.find_element(By.CSS_SELECTOR, ".complex_infos .price_default").text
    if not price:
        continue

    print(f"{place} --> {price}")

    maps.append({
        '정보': place, 
        '가격': price
    })

print()
print(maps)
# Out:
# 청솔계룡 --> 10.4억
# 상록라이프 --> 18억
#
# [{'정보': '청솔계룡', '가격': '10.4억'}, {'정보': '상록라이프', '가격': '18억'}]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome()

try:
    driver.get("https://www.google.com"/)
    # 검색 상자를 찾기
    search_box = driver.find_element("name", "q")
    # 검색어 입력
    search_box.send_keys("OpenAI")
    # 엔터 키 입력
    search_box.send_keys(Keys.ENTER)
    # 검색 결과가 로드될 때까지 잠시 대기
    time.sleep(3)
    # 첫 번째 검색 결과 클릭
    first_result = driver.find_element("css selector", "h3")
    first_result.click()
    # 잠시 대기
    time.sleep(10)
finally:
    driver.quit()
# Out:
#   Cell In[5], line 8
#     driver.get("https://www.google.com"/)
#                                         ^
# SyntaxError: invalid syntax

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
import pyautogui
import pyperclip
import webbrowser
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup

chrome_options = Options()

# 브라우저 꺼짐 방지
chrome_options.add_experimental_option('detach', True)

# 불필요한 에러 메시지 노출 방지
chrome_options.add_experimental_option('excludeSwitches', ['enable-logging'])

driver = webdriver.Chrome(options = chrome_options)

driver.maximize_window()
time.sleep(1)
driver.get('https://www.jobkorea.co.kr/')


time.sleep(5)
such = driver.find_element(By.ID,'stext')
such.send_keys("파이썬 개발")
such.send_keys(Keys.ENTER)

jobinfo = []
items = driver.find_elements(By.CSS_SELECTOR,'crticle.list-item')

for item in items:
    try:
        info =job.get_attribure('data-gainfo')
        company = json.loads(info)
        jobinfo.append(company)
        print(f"회사:{comapny['dimension48']},제목:{company['dimension45']}")
    except:
        continue
print(jobinfo)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
import pyautogui
import pyperclip
import webbrowser
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

chrome_options = Options()

# 브라우저 꺼짐 방지
chrome_options.add_experimental_option('detach', True)

# 불필요한 에러 메시지 노출 방지
chrome_options.add_experimental_option('excludeSwitches', ['enable-logging'])

driver = webdriver.Chrome(options = chrome_options)

driver.maximize_window()
time.sleep(1)

driver.get('https://www.saramin.co.kr/zf_user/?NaPm=ct%3Dm4b3ersg%7Cci%3Dcheckout%7Ctr%3Dds%7Ctrx%3Dnull%7Chk%3D1c48c33f31cf1d91e1ceee91acd12bd0fa94f7ef')
time.sleep(5)

such = driver.find_element(By.ID,'btn_search')
such.click()
such2 = driver.find_element(By.ID,'ipt_keyword_recruit')
such2.send_keys("파이썬")
such2.send_keys(Keys.ENTER)

job_list = []
items = driver.find_elements(By.CSS_SELECTOR,'div.item_recruit')

for item in items:
    title = item.find_element(By.CSS_SELECTOR,"h2.job_tit").text
    company = item.find_element(By.CSS_SELECTOR,"strong.corp_name").text

    job_list.append({
        '제목': title, 
        '회사': company
    })
for i in job_list:
    print(i)
# Out:
# {'제목': '파이썬(Python) 백엔드 개발자 모십니다', '회사': '(주)케이엘피'}
# {'제목': '파이썬 프로그램 개발자', '회사': '(주)뉴로다임'}
# {'제목': '파이썬(Python) 크롤링 가능하신분 구합니다.', '회사': '(주)케이엘피'}
# {'제목': '파이썬(Python) 기반의 풀스택 개발자 모십니다.', '회사': '(주)케이엘피'}
# {'제목': '[(주)아이젝스] Mac Agent 파이썬 개발자 채용 공고', '회사': '(주)아이젝스'}
# {'제목': '파이썬(Python, AWS) 경력 개발자 채용', '회사': '(주)한국미용데이터'}
# {'제목': '[여의도/338만] 한국평가데이터 DB분석 및 컨설팅 (SQL,파이썬)', '회사': '에이스휴먼파워(주)'}
# {'제목': '파이썬(Python) 및 앱(ios/안드로이드) 개발자 모집', '회사': '주식회사비전코어'}
# {'제목': '파이썬 개발자 경력직 모집, AI vision 경험자 우대', '회사': '(주)댄디테크앤리얼티'}
# {'제목': '[(주)도로시] QGIS 플러그인 파이썬(Python) 개발자 모집', '회사': '(주)도로시'}
# {'제목': '[IT 솔루션 및 통합서비스 전문기업] 파이썬(Python) 개발자', '회사': '에이치알포유(주)'}
# {'제목': '파이썬(웹백엔드) 운영 관리 개발자 채용', '회사': '제스트클라우드(주)'}
# {'제목': '파이썬(Python) 및 앱(ios/안드로이드) 개발자', '회사': '주식회사비전코어'}
# {'제목': '[유망 스타트업] [경력] 백엔드 개발자 채용 (파이썬)', '회사': '링크루트'}
# {'제목': '대기업 서비스 스벨트/파이썬 개발자 채용', '회사': '(주)아이이에이'}
# {'제목': '시니어 파이썬 백엔드 엔지니어 채용', '회사': '(주)알로카도스'}
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
import pyautogui
import pyperclip
import webbrowser
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

chrome_options = Options()

# 브라우저 꺼짐 방지
chrome_options.add_experimental_option('detach', True)

# 불필요한 에러 메시지 노출 방지
chrome_options.add_experimental_option('excludeSwitches', ['enable-logging'])

driver = webdriver.Chrome(options = chrome_options)

driver.maximize_window()
time.sleep(1)

driver.get('https://www.saramin.co.kr/zf_user/?NaPm=ct%3Dm4b3ersg%7Cci%3Dcheckout%7Ctr%3Dds%7Ctrx%3Dnull%7Chk%3D1c48c33f31cf1d91e1ceee91acd12bd0fa94f7ef')
time.sleep(5)

such = driver.find_element(By.ID,'btn_search')
such.click()
such2 = driver.find_element(By.ID,'ipt_keyword_recruit')
such2.send_keys("파이썬")
such2.send_keys(Keys.ENTER)

job_list = []
try:
    while True:
        
        items = driver.find_elements(By.CSS_SELECTOR, 'div.item_recruit')
        for item in items:
            title = item.find_element(By.CSS_SELECTOR, "h2.job_tit").text
            company = item.find_element(By.CSS_SELECTOR, "strong.corp_name").text

            job_list.append({'제목': title, '회사': company})
        
        print(f"{len(job_list)}개의 데이터를 수집했습니다.")  
     
        try:
            next_button = driver.find_element(By.CSS_SELECTOR, 
                '#recruit_info_list > div.content_bottom > div > a.btnNext.page_move.track_event')
            next_button.click()  
            time.sleep(3) 
        except:
            print("다음 페이지가 없습니다. 크롤링 종료.")
            break

finally:
    driver.quit()

for job in job_list:
    print(job)
# Out:
# 40개의 데이터를 수집했습니다.
# 80개의 데이터를 수집했습니다.
# 120개의 데이터를 수집했습니다.
# 160개의 데이터를 수집했습니다.
# 200개의 데이터를 수집했습니다.
# 240개의 데이터를 수집했습니다.
# 다음 페이지가 없습니다. 크롤링 종료.
# {'제목': '파이썬(Python) 백엔드 개발자 모십니다', '회사': '(주)케이엘피'}
# {'제목': '파이썬 프로그램 개발자', '회사': '(주)뉴로다임'}
# {'제목': '파이썬(Python) 크롤링 가능하신분 구합니다.', '회사': '(주)케이엘피'}
# {'제목': '파이썬(Python) 기반의 풀스택 개발자 모십니다.', '회사': '(주)케이엘피'}
# {'제목': '[(주)아이젝스] Mac Agent 파이썬 개발자 채용 공고', '회사': '(주)아이젝스'}
# {'제목': '파이썬(Python, AWS) 경력 개발자 채용', '회사': '(주)한국미용데이터'}
# {'제목': '[여의도/338만] 한국평가데이터 DB분석 및 컨설팅 (SQL,파이썬)', '회사': '에이스휴먼파워(주)'}
# {'제목': '파이썬(Python) 및 앱(ios/안드로이드) 개발자 모집', '회사': '주식회사비전코어'}
# {'제목': '파이썬 개발자 경력직 모집, AI vision 경험자 우대', '회사': '(주)댄디테크앤리얼티'}
# {'제목': '[(주)도로시] QGIS 플러그인 파이썬(Python) 개발자 모집', '회사': '(주)도로시'}
# {'제목': '[IT 솔루션 및 통합서비스 전문기업] 파이썬(Python) 개발자', '회사': '에이치알포유(주)'}
# {'제목': '파이썬(웹백엔드) 운영 관리 개발자 채용', '회사': '제스트클라우드(주)'}
# {'제목': '파이썬(Python) 및 앱(ios/안드로이드) 개발자', '회사': '주식회사비전코어'}
# {'제목': '[유망 스타트업] [경력] 백엔드 개발자 채용 (파이썬)', '회사': '링크루트'}
# ...
